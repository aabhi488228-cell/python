# %%
print("hello world")
# Out:
# hello world

# %%
a=5
b=5
sum=a+b
print("sum is:",sum)
# Out:
# sum is: 10

# %% [markdown]
# ### printing"hello world"

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# #### arithmetic operation
# ###### initalization of values

# %%
a=5
b=7
print("sum=",a+b)
# Out:
# sum= 12

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print("a=",a)
print("b=",b)
print("sum=",a+b)
# Out:
# enter a 5
# enter b 7
# a= 5
# b= 7
# sum= 12

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 709A-02B6
#
#  Directory of C:\Users\aabhi
#
# 03/26/2026  12:09 AM    <DIR>          .
# 01/21/2026  08:39 AM    <DIR>          ..
# 02/21/2026  12:08 PM    <DIR>          .anaconda
# 03/25/2026  11:18 AM                16 .bash_history
# 03/26/2026  12:13 AM    <DIR>          .conda
# 02/21/2026  12:14 PM    <DIR>          .continuum
# 02/21/2026  12:22 PM    <DIR>          .copilot
# 03/25/2026  11:32 AM                51 .gitconfig
# 03/25/2026  12:41 PM    <DIR>          .ipynb_checkpoints
# 03/25/2026  12:41 PM    <DIR>          .ipython
# 03/25/2026  12:34 PM    <DIR>          .jupyter
# 03/25/2026  11:13 AM               212 .python_history
# 01/26/2026  07:27 PM    <DIR>          .vscode
# 01/31/2026  02:53 PM    <DIR>          ansel
# 01/19/2026  03:19 PM    <DIR>          Contacts
# 01/31/2026  04:35 PM    <DIR>          CrossDevice
# 01/19/2026  04:42 PM    <DIR>          Documents
# ...

# %%
print("welcome","to","python")
# Out:
# welcome to python

# %% [markdown]
# ###### variables

# %%
a=10
b=20
print("a+b")
# Out:
# a+b

# %%
a=10
b=20
print(a-b)
# Out:
# -10

# %%
a=10
b=67
print(a*b)
# Out:
# 670

# %%
a=89
b=90
print(a/b)
# Out:
# 0.9888888888888889

# %%
a=10
b=30
print(a//b)
# Out:
# 0

# %%
a=input("enter a:")
b=input("enter b:")
print(a+b)
# Out:
# enter a: 10
# enter b: 20
# 1020

# %%
a=int(input("enter a:"))
b=int(input("enter b:"))
print(a+b)
# Out:
# enter a: 90
# enter b: 30
# 120

# %%
a=10
b=30
c=40
average=(a+b+c)/3
print("the average of the three numbers are:",average)
# Out:
# the average of the three numbers are: 26.666666666666668

# %%
a=10
b=30
c=34
print("ADDITION=",a+b)
print("SUBTRACTION=",a-b)
print("MULTIPLICATION=",a*b)
# Out:
# ADDITION= 40
# SUBTRACTION= -20
# MULTIPLICATION= 300

# %%
p=100.30
t=200.2
r=350.3

SI=(p*t*r)/100
print("the simple intrest is:",SI)
# Out:
# the simple intrest is: 70340.45017999999

# %%
a=20
b=10

temp=a
a=b
b=temp
print("a=",a)
print("b=",b)
# Out:
# a= 10
# b= 20

# %%
a=3
print("square of a is:",a*a)
# Out:
# square of a is: 9

# %%
a=9
print(a ** 0.5)
# Out:
# 3.0

# %% [markdown]
# ### 1A ADD-SUB

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print("add:",a+b)
print("sub:",a-b)
# Out:
# enter a 10
# enter b 20
# add: 30
# sub: -10

# %% [markdown]
# #### 1B OPERATORS

# %%
a=int(input("enter a "))
b=int(input("enter b"))
print(a>b)
print(a<b)
# Out:
# enter a  10
# enter b 20
# False
# True

# %% [markdown]
# #### 1C ASSIGN-OPERATION

# %%
a=int(input("enetr a"))
a*=10
a+=5
b=a
print("a=",a)
print("b=",b)
# Out:
# enetr a 10
# a= 105
# b= 105

# %% [markdown]
# #### 1D BINARY/OPERATION

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print(a/b)
print(a&b)
# Out:
# enter a 10
# enter b 20
# 0.5
# 0

# %% [markdown]
# ##### 1E MEMBERSHIP-OPERATIOR

# %%
a=[1,2,3]
print(2 in a)
# Out:
# True

# %%
a=[1,2,3]
print(5 in a)
# Out:
# False

# %%
a=[1,2,3]
print(4 not in a)
# Out:
# True

# %% [markdown]
# ##### 1F IDENTITY-OPERATION

# %%
a=[1,2,3]
b=[1,2,3]
print(a is b)
print(a==b)
c=b
print(b is c)
# Out:
# False
# True
# True

# %% [markdown]
# #### 2.control structure

# %% [markdown]
# ##### 2A POSITIVITY.PY

# %%
a=int(input("enter a"))
if a>0:
      print("the number is positive")
else: 
    print("the number is negative")
# Out:
# enter a -30
# the number is negative

# %% [markdown]
# ##### 2B even or odd

# %%
a=int(input("enter a"))
if (a%2==0):
    print("even")
else:
     print("odd")
# Out:
# enter a 45
# odd

# %%
a=int(input("enetr a"))
if a>0:
    print("the number is positive")
if a<0:
    print("the number is negative")
if (a%2==0):
        print(" the given number is even")
else:
        print("the given number is odd")
# Out:
# enetr a -2
# the number is negative
#  the given number is even

# %%
age=int(input("enter the age"))
if age>18:
    print("elligible for vote")
else:
    print("not elligible")
# Out:
# enter the age 12
# not elligible

# %%
a=int(input("enter a"))
b=int(input("enetr b"))
c=int(input("enetr c"))
if a>b and a>c:
    print("the largest number is a")
if b>a and b>c:
    print("the largest number is b")
else:
    print("the largest number is c")
# Out:
# enter a 12
# enetr b 23
# enetr c 34
# the largest number is c

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<=5:
    print(i)
    i=i+1;
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print("hello")
# Out:
# hello

# %%
i=1
while i<=5:
    print(i)
    i=i+1;
    if i==4:
        break
# Out:
# 1
# 2
# 3

# %%
i=1
while i<=5:
    i=i+1
    if i==4:
        continue;
        print(i)

# %%
a=int(input("enetr a "))
if a>0:
    print("the number is positive")
if a<0:
    print("the number is negative")
# Out:
# enetr a  2
# the number is positive

# %%
ch=(input("enetr character"))
if ch in "aeiou":
    print("character is vowel")
else:
    print("charater is consonents")
# Out:
# enetr character a
# character is vowel

# %%
num=int(input("enter num"))
if num%5==0:
    print(" devisible by 5")
else:
    print("not divisible by 5")
# Out:
# enter num 25
#  devisible by 5

# %%
a=int(input("enter a "))
b=int(input("enter b"))
c=int(input("enetr c"))
if a>b and a>c:
    print(" a is the largest")
if b>a and b>c:
    print("b is the largest ")
else:
    print("c is the largest ")
# Out:
# enter a  12
# enter b 23
# enetr c 4
# b is the largest

# %%
num=int(input("enter num"))
if num%4==0 and num%100!=0:
    print("it is a leap year")
else:
    print("not a leap year")
# Out:
# enter num 2028
# it is a leap year

# %% [markdown]
# ### grade calculations based on the marks

# %%
marks=int(input("enetr marks "))
if  marks>=90:
    print("grade=","A")
elif    marks>=70:
    print("grade=","B")
elif    marks>=50:
    print("grade=","C")
else:
    print("fail")
# Out:
# enetr marks  99
# grade= A

# %%
a=int(input("enter a"))
if a>0:
    print("the number is positive")
elif a<0:
    print("the number is negative")
else:
    print("the number is zero")
# Out:
# enter a 0
# the number is zero

# %%
## print numbers from 1 to 10

# %%
i=1
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
num=int(input("enter the number"))
for i in range(1,11):
    print(num,"x",i,"=",num*i)
# Out:
# enter the number 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
